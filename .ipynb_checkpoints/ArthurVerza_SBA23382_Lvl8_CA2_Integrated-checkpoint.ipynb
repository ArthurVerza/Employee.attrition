# %%
# Load libraries
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
import numpy as np



import warnings
warnings.filterwarnings('ignore')


pd.set_option("display.max_columns",500)
pd.set_option("display.max_rows",500)

# %%
import hvplot.pandas
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# load dataset
df = pd.read_csv("Employee_Attrition.csv", header = 0)

# %%
df.head()
# Out:
#          Age Attrition     BusinessTravel    DailyRate  \
# 0  41.920786       Yes      Travel_Rarely   990.110009
# 1  51.589037        No  Travel_Frequently   276.776030
# 2  33.131540       Yes      Travel_Rarely  1204.158501
# 3  34.707073        No  Travel_Frequently  1352.752432
# 4  24.790188        No      Travel_Rarely   485.053333
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales          1.016716   1.770313  Life Sciences
# 1  Research & Development               NaN   1.035333  Life Sciences
# 2  Research & Development          2.198662   2.118801          Other
# 3                   Sales          2.937851   3.670674  Life Sciences
# 4  Research & Development          1.988953   1.120496        Medical
#
#    EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0       1.033298        1.054148                 2.146294    Male   93.827486
# 1       0.944859        2.107031                 3.470803    Male   52.304157
# 2       0.810809        4.008125                 3.979420    Male   87.271332
# 3       0.822976        4.587269                 3.734705  Female   56.378982
# 4            NaN        7.228740                 1.079412    Male   40.433887
#
#    JobInvolvement  JobLevel                JobRole  JobSatisfaction  \
# 0        3.426960  2.464492        Sales Executive         3.397665
# 1        1.813458  1.788697     Research Scientist         1.584059
# 2        1.877226  0.833488  Laboratory Technician         3.301009
# 3        2.932646  1.095372     Research Scientist         3.220844
# 4        3.117739  0.937746  Laboratory Technician         1.697330
#
#   MaritalStatus  MonthlyIncome   MonthlyRate  NumCompaniesWorked Over18  \
# 0        Single    6438.949336  20845.103714            7.077818      Y
# 1       Married    4457.659622  24877.898697            1.114423      Y
# 2        Single    2124.545220   2262.942954            5.539591      Y
# 3       Married    2771.699080  27189.905714            0.772793    NaN
# 4       Married    3254.601575  17675.541599           10.118125    NaN
#
#   OverTime  PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 0      Yes           9.898765           2.844897                  1.012832
# 1       No                NaN           4.120281                  4.312008
# 2      Yes          15.401596           2.781168                  2.332558
# 3      Yes           9.757546           2.769576                  3.029591
# 4      NaN          11.920147           3.282183                       NaN
#
#    StandardHours  StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0      95.612654          0.000000           8.063833               0.000000
# 1      85.370868          1.104642           8.965059               3.264952
# 2      76.248084          0.000000           8.427238               3.004521
# 3      75.888697          0.000000           7.662606               2.856001
# 4      72.670937          0.953012           6.241733               2.814719
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0         1.052104        5.795945            3.993896
# 1         2.526470       10.070232            7.937505
# 2         2.924784        0.000000            0.000000
# 3         3.117053        8.435324            5.563667
# 4         3.112317        2.040124            1.970786
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                 0.000000              4.594972
# 1                 1.032295              5.901207
# 2                 0.000000              0.000000
# 3                 2.845429              0.000000
# 4                 2.495949              2.219353

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1323 non-null   float64
#  1   Attrition                 1323 non-null   object
#  2   BusinessTravel            1323 non-null   object
#  3   DailyRate                 1323 non-null   float64
#  4   Department                1323 non-null   object
#  5   DistanceFromHome          1323 non-null   float64
#  6   Education                 1323 non-null   float64
#  7   EducationField            1323 non-null   object
#  8   EmployeeCount             1323 non-null   float64
#  9   EmployeeNumber            1323 non-null   float64
#  10  EnvironmentSatisfaction   1323 non-null   float64
#  11  Gender                    1323 non-null   object
#  12  HourlyRate                1323 non-null   float64
#
#        TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# count        1323.000000            1323.000000      1323.000000
# mean           11.426152               2.811756         2.762825
# std             8.075870               1.329044         0.761802
# min             0.000000               0.000000         0.799138
# 25%             5.953221               1.967328         2.193390
# 50%             9.306742               2.690934         2.899807
# 75%            15.324548               3.366949         3.206117
# max            47.641892               7.503201         4.856086
#
#        YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# count     1323.000000         1323.000000              1323.000000
# mean         6.933624            4.233363                 2.160710
# std          6.046798            3.658111                 3.221481
# min          0.000000            0.000000                 0.000000
# 25%          2.673269            1.824392                 0.000000
# 50%          5.422160            2.968874                 0.967140
# 75%          9.238005            7.052591                 2.586631
# max         36.848408           19.091844                17.273662
#
#        YearsWithCurrManager
# count           1323.000000
# mean               4.117695
# std                3.594053
# min                0.000000
# 25%                1.687177
# 50%                2.939240
# 75%                6.987964
# max               19.976003

# %%
df.isnull().sum()
# Out:
# Age                         147
# Attrition                   147
# BusinessTravel              147
# DailyRate                   147
# Department                  147
# DistanceFromHome            147
# Education                   147
# EducationField              147
# EmployeeCount               147
# EmployeeNumber              147
# EnvironmentSatisfaction     147
# Gender                      147
# HourlyRate                  147
# JobInvolvement              147
# JobLevel                    147
# JobRole                     147
# JobSatisfaction             147
# MaritalStatus               147
# MonthlyIncome               147
# MonthlyRate                 147
# NumCompaniesWorked          147
# Over18                      147
# OverTime                    147
# PercentSalaryHike           147
# PerformanceRating           147
# RelationshipSatisfaction    147
# StandardHours               147
# StockOptionLevel            147
# TotalWorkingYears           147
# TrainingTimesLastYear       147
# WorkLifeBalance             147
# YearsAtCompany              147
# YearsInCurrentRole          147
# YearsSinceLastPromotion     147
# YearsWithCurrManager        147
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df=df.round(0)

# %%
df.head()
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0  42.0       Yes      Travel_Rarely      990.0                   Sales
# 1  52.0        No  Travel_Frequently      277.0  Research & Development
# 2  33.0       Yes      Travel_Rarely     1204.0  Research & Development
# 3  35.0        No  Travel_Frequently     1353.0                   Sales
# 4  25.0        No      Travel_Rarely      485.0  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0               1.0        2.0  Life Sciences            1.0             1.0
# 1               NaN        1.0  Life Sciences            1.0             2.0
# 2               2.0        2.0          Other            1.0             4.0
# 3               3.0        4.0  Life Sciences            1.0             5.0
# 4               2.0        1.0        Medical            NaN             7.0
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                      2.0    Male        94.0             3.0       2.0
# 1                      3.0    Male        52.0             2.0       2.0
# 2                      4.0    Male        87.0             2.0       1.0
# 3                      4.0  Female        56.0             3.0       1.0
# 4                      1.0    Male        40.0             3.0       1.0
#
#                  JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0        Sales Executive              3.0        Single         6439.0
# 1     Research Scientist              2.0       Married         4458.0
# 2  Laboratory Technician              3.0        Single         2125.0
# 3     Research Scientist              3.0       Married         2772.0
# 4  Laboratory Technician              2.0       Married         3255.0
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0      20845.0                 7.0      Y      Yes               10.0
# 1      24878.0                 1.0      Y       No                NaN
# 2       2263.0                 6.0      Y      Yes               15.0
# 3      27190.0                 1.0    NaN      Yes               10.0
# 4      17676.0                10.0    NaN      NaN               12.0
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                3.0                       1.0           96.0
# 1                4.0                       4.0           85.0
# 2                3.0                       2.0           76.0
# 3                3.0                       3.0           76.0
# 4                3.0                       NaN           73.0
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0               0.0                8.0                    0.0
# 1               1.0                9.0                    3.0
# 2               0.0                8.0                    3.0
# 3               0.0                8.0                    3.0
# 4               1.0                6.0                    3.0
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0              1.0             6.0                 4.0
# 1              3.0            10.0                 8.0
# 2              3.0             0.0                 0.0
# 3              3.0             8.0                 6.0
# 4              3.0             2.0                 2.0
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                      0.0                   5.0
# 1                      1.0                   6.0
# 2                      0.0                   0.0
# 3                      3.0                   0.0
# 4                      2.0                   2.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1323 non-null   float64
#  1   Attrition                 1323 non-null   object
#  2   BusinessTravel            1323 non-null   object
#  3   DailyRate                 1323 non-null   float64
#  4   Department                1323 non-null   object
#  5   DistanceFromHome          1323 non-null   float64
#  6   Education                 1323 non-null   float64
#  7   EducationField            1323 non-null   object
#  8   EmployeeCount             1323 non-null   float64
#  9   EmployeeNumber            1323 non-null   float64
#  10  EnvironmentSatisfaction   1323 non-null   float64
#  11  Gender                    1323 non-null   object
#  12  HourlyRate                1323 non-null   float64
#  13  JobInvolvement            1323 non-null   float64
#  14  JobLevel                  1323 non-null   float64
#  15  JobRole                   1323 non-null   object
#  16  JobSatisfaction           1323 non-null   float64
#  17  MaritalStatus             1323 non-null   object
#  18  MonthlyIncome             1323 non-null   float64
#  19  MonthlyRate               1323 non-null   float64
#  20  NumCompaniesWorked        1323 non-null   float64
#  21  Over18                    1323 non-null   object
#  22  OverTime                  1323 non-null   object
#  23  PercentSalaryHike         1323 non-null   float64
#  24  PerformanceRating         1323 non-null   float64
#  25  RelationshipSatisfaction  1323 non-null   float64
#  26  StandardHours             1323 non-null   float64
#  27  StockOptionLevel          1323 non-null   float64
#  28  TotalWorkingYears         1323 non-null   float64
#  29  TrainingTimesLastYear     1323 non-null   float64
#  30  WorkLifeBalance           1323 non-null   float64
#  31  YearsAtCompany            1323 non-null   float64
#  32  YearsInCurrentRole        1323 non-null   float64
#  33  YearsSinceLastPromotion   1323 non-null   float64
#  34  YearsWithCurrManager      1323 non-null   float64
# dtypes: float64(26), object(9)
# memory usage: 402.1+ KB

# %%
for column in df.columns:
    print(f"{column}: Number of unique values {df[column].nunique()}")
    print(" ")
# Out:
# Age: Number of unique values 53
#
# Attrition: Number of unique values 2
#
# BusinessTravel: Number of unique values 3
#
# DailyRate: Number of unique values 866
#
# Department: Number of unique values 3
#
# DistanceFromHome: Number of unique values 33
#
# Education: Number of unique values 6
#
# EducationField: Number of unique values 6
#
# EmployeeCount: Number of unique values 1
#
# EmployeeNumber: Number of unique values 992
#
# EnvironmentSatisfaction: Number of unique values 5
#
# Gender: Number of unique values 2
#
# HourlyRate: Number of unique values 94
#
# JobInvolvement: Number of unique values 5
#
# JobLevel: Number of unique values 6
#
# JobRole: Number of unique values 9
#
# JobSatisfaction: Number of unique values 5
#
# MaritalStatus: Number of unique values 3
#
# MonthlyIncome: Number of unique values 1246
#
# MonthlyRate: Number of unique values 1287
#
# NumCompaniesWorked: Number of unique values 12
#
# Over18: Number of unique values 1
#
# OverTime: Number of unique values 2
#
# PercentSalaryHike: Number of unique values 23
#
# PerformanceRating: Number of unique values 4
#
# RelationshipSatisfaction: Number of unique values 5
#
# StandardHours: Number of unique values 51
#
# StockOptionLevel: Number of unique values 4
#
# TotalWorkingYears: Number of unique values 44
#
# TrainingTimesLastYear: Number of unique values 9
#
# WorkLifeBalance: Number of unique values 5
#
# YearsAtCompany: Number of unique values 36
#
# YearsInCurrentRole: Number of unique values 20
#
# YearsSinceLastPromotion: Number of unique values 18
#
# YearsWithCurrManager: Number of unique values 19

# %%
df.drop(['EmployeeCount', 'EmployeeNumber', 'Over18', 'StandardHours'], axis="columns", inplace=True)

# %% [markdown]
# the dropped features aren't useful because have only 1 unique value and employee number is individual so Im going to dro it

# %%
object_col = []
for column in df.columns:
    if df[column].dtype == object and len(df[column].unique()) <= 30:
        object_col.append(column)
        print(f"{column} : {df[column].unique()}")
        print(df[column].value_counts())
        print(" ")

object_col.remove('Attrition')
# Out:
# Attrition : ['Yes' 'No' nan]
# Attrition
# No     1065
# Yes     258
# Name: count, dtype: int64
#
# BusinessTravel : ['Travel_Rarely' 'Travel_Frequently' nan 'Non-Travel']
# BusinessTravel
# Travel_Rarely        890
# Travel_Frequently    279
# Non-Travel           154
# Name: count, dtype: int64
#
# Department : ['Sales' 'Research & Development' nan 'Human Resources']
# Department
# Research & Development    824
# Sales                     393
# Human Resources           106
# Name: count, dtype: int64
#
# EducationField : ['Life Sciences' 'Other' 'Medical' 'Technical Degree' nan 'Marketing'
#  'Human Resources']
# EducationField
# Life Sciences       504
# Medical             397
# Marketing           149
# Technical Degree    141
# Other                83
# Human Resources      49
# Name: count, dtype: int64
#
# Gender : ['Male' 'Female' nan]
# Gender
# Male      783
# Female    540
# Name: count, dtype: int64
#
# JobRole : ['Sales Executive' 'Research Scientist' 'Laboratory Technician' nan
#  'Healthcare Representative' 'Manufacturing Director' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources']
# JobRole
# Sales Executive              281
# Research Scientist           257
# Laboratory Technician        229
# Manufacturing Director       122
# Healthcare Representative    118
# Manager                      101
# Research Director             80
# Sales Representative          75
# Human Resources               60
# Name: count, dtype: int64
#
# MaritalStatus : ['Single' 'Married' 'Divorced' nan]
# MaritalStatus
# Married     596
# Single      429
# Divorced    298
# Name: count, dtype: int64
#
# OverTime : ['Yes' 'No' nan]
# OverTime
# No     929
# Yes    394
# Name: count, dtype: int64

# %%
len(object_col)
# Out:
# 7

# %%
label = LabelEncoder()
df["Attrition"] = label.fit_transform(df.Attrition)

# %%
disc_col = []
for column in df.columns:
    if df[column].dtypes != object and df[column].nunique() < 30:
        print(f"{column} : {df[column].unique()}")
        disc_col.append(column)
        print(" ")
disc_col.remove('Attrition')
# Out:
# Attrition : [1 0 2]
#
# Education : [ 2.  1.  4. nan  3.  5.  6.]
#
# EnvironmentSatisfaction : [ 2.  3.  4.  1. nan  5.]
#
# JobInvolvement : [ 3.  2.  4.  5. nan  1.]
#
# JobLevel : [ 2.  1.  3. nan  4.  5.  6.]
#
# JobSatisfaction : [ 3.  2. nan  5.  1.  4.]
#
# NumCompaniesWorked : [ 7.  1.  6. 10.  0.  4.  2.  5. nan  3.  9.  8. 11.]
#
# PercentSalaryHike : [10. nan 15. 12. 13. 19. 21. 11. 17.  8. 23. 20. 14. 16.  9. 24. 18. 22.
#  28. 25. 27. 26. 29. 30.]
#
# PerformanceRating : [ 3.  4.  2. nan  5.]
#
# RelationshipSatisfaction : [ 1.  4.  2.  3. nan  5.]
#
# StockOptionLevel : [ 0.  1.  3.  2. nan]
#
# TrainingTimesLastYear : [ 0.  3.  2. nan  5.  1.  4.  6.  7.  8.]
#
# WorkLifeBalance : [ 1.  3.  2. nan  5.  4.]
#
# YearsInCurrentRole : [ 4.  8.  0.  6.  2. nan  7.  3. 14.  1. 15.  5. 13. 12. 10. 11.  9. 17.
#  18. 16. 19.]
#
# YearsSinceLastPromotion : [ 0.  1.  3.  2. nan  4.  8.  7.  5. 17.  9.  6. 13. 11. 10. 16. 14. 12.
#  15.]
#
# YearsWithCurrManager : [ 5.  6.  0.  2.  7.  3.  9.  8. nan 10. 18.  1. 12.  4. 11. 15. 14. 16.
#  13. 20.]

# %%
cont_col = []
for column in df.columns:
    if df[column].dtypes != object and df[column].nunique() > 30:
        print(f"{column} : Minimum: {df[column].min()}, Maximum: {df[column].max()}")
        cont_col.append(column)
        print(" ")
# Out:
# Age : Minimum: 15.0, Maximum: 69.0
#
# DailyRate : Minimum: 87.0, Maximum: 1784.0
#
# DistanceFromHome : Minimum: 1.0, Maximum: 34.0
#
# HourlyRate : Minimum: 24.0, Maximum: 123.0
#
# MonthlyIncome : Minimum: 891.0, Maximum: 22858.0
#
# MonthlyRate : Minimum: 1568.0, Maximum: 32752.0
#
# TotalWorkingYears : Minimum: 0.0, Maximum: 48.0
#
# YearsAtCompany : Minimum: 0.0, Maximum: 37.0

# %%
# Increase the figure size
plt.figure(figsize=(12, 6))

# Your count plot code
sns.countplot(x="DistanceFromHome", hue="Attrition", data=df)

# Add labels and a title for better clarity
plt.xlabel("Distance From Home")
plt.ylabel("Count")
plt.title("Attrition Count by Distance From Home")

# Show the plot
plt.show()

# %% [markdown]
# The workers with low JobLevel, MonthlyIncome, YearAtCompany, and TotalWorkingYears are more likely to quit there jobs.
# BusinessTravel : The workers who travel alot are more likely to quit then other employees.
#
# Department : The worker in Research & Development are more likely to stay then the workers on other departement.
#
# EducationField : The workers with Human Resources and Technical Degree are more likely to quit then employees from other fields of educations.
#
# Gender : The Male are more likely to quit.
#
# JobRole : The workers in Laboratory Technician, Sales Representative, and Human Resources are more likely to quit the workers in other positions.
#
# MaritalStatus : The workers who have Single marital status are more likely to quit the Married, and Divorced.
#
# OverTime : The workers who work more hours are likely to quit then others.

# %%
for column in df.columns:
    if df[column].dtype == 'O':  # Check if the column has object (string) dtype
        df[column] = pd.to_numeric(df[column], errors='coerce')

print(df)
# Out:
#        Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0
#
#       WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                 1.0             6.0                 4.0
# 1                 3.0            10.0                 8.0
# 2                 3.0             0.0                 0.0
# 3                 3.0             8.0                 6.0
# 4                 3.0             2.0                 2.0
# ...               ...             ...                 ...
# 1465              3.0             5.0                 2.0
# 1466              3.0             7.0                 8.0
# 1467              3.0             6.0                 2.0
# 1468              2.0             8.0                 7.0
# 1469              4.0             4.0                 3.0
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                         0.0                   5.0
# 1                         1.0                   6.0
# 2                         0.0                   0.0
# 3                         3.0                   0.0
# 4                         2.0                   2.0
# ...                       ...                   ...
# 1465                      0.0                   NaN
# 1466                      1.0                   7.0
# 1467                      0.0                   3.0
# 1468                      0.0                   NaN
# 1469                      1.0                   2.0
#
# [1470 rows x 31 columns]

# %%
col = df.corr().nlargest(20, "Attrition").Attrition.index
plt.figure(figsize=(15, 15))
sns.heatmap(df[col].corr(), annot=True, cmap="RdYlGn", annot_kws={"size":10})
# Out:
# <Axes: >

# %%
pip install hvplot holoviews
# Out:
# WARNING: Ignoring invalid distribution ~atplotlib (/Users/arthurverza/anaconda3/lib/python3.11/site-packages)
# Requirement already satisfied: hvplot in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (0.8.4)
# Requirement already satisfied: holoviews in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (1.17.0)
# Requirement already satisfied: bokeh>=1.0.0 in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (from hvplot) (3.2.2)
# Requirement already satisfied: colorcet>=2 in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (from hvplot) (3.0.1)
# Requirement already satisfied: pandas in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (from hvplot) (2.1.3)
# Requirement already satisfied: numpy>=1.15 in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (from hvplot) (1.23.5)
# Requirement already satisfied: packaging in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (from hvplot) (23.0)
# Requirement already satisfied: panel>=0.11.0 in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (from hvplot) (1.2.1)
# Requirement already satisfied: param>=1.9.0 in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (from hvplot) (1.13.0)
# Requirement already satisfied: pyviz-comms>=0.7.4 in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (from holoviews) (2.3.0)
# Requirement already satisfied: Jinja2>=2.9 in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (from bokeh>=1.0.0->hvplot) (3.1.2)
# Requirement already satisfied: contourpy>=1 in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (from bokeh>=1.0.0->hvplot) (1.0.5)
# Requirement already satisfied: pillow>=7.1.0 in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (from bokeh>=1.0.0->hvplot) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (from bokeh>=1.0.0->hvplot) (6.0)
# Requirement already satisfied: tornado>=5.1 in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (from bokeh>=1.0.0->hvplot) (6.3.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (from bokeh>=1.0.0->hvplot) (2022.9.0)
# Requirement already satisfied: pyct>=0.4.4 in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (from colorcet>=2->hvplot) (0.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (from pandas->hvplot) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (from pandas->hvplot) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (from pandas->hvplot) (2023.3)
# Requirement already satisfied: markdown in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (from panel>=0.11.0->hvplot) (3.4.1)
# Requirement already satisfied: markdown-it-py in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (from panel>=0.11.0->hvplot) (2.2.0)
# Requirement already satisfied: linkify-it-py in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (from panel>=0.11.0->hvplot) (2.0.0)
# Requirement already satisfied: mdit-py-plugins in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (from panel>=0.11.0->hvplot) (0.3.0)
# Requirement already satisfied: requests in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (from panel>=0.11.0->hvplot) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.0 in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (from panel>=0.11.0->hvplot) (4.65.0)
# Requirement already satisfied: bleach in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (from panel>=0.11.0->hvplot) (4.1.0)
# Requirement already satisfied: typing-extensions in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (from panel>=0.11.0->hvplot) (4.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (from Jinja2>=2.9->bokeh>=1.0.0->hvplot) (2.0.1)
# Requirement already satisfied: six>=1.5 in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->hvplot) (1.16.0)
# Requirement already satisfied: webencodings in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (from bleach->panel>=0.11.0->hvplot) (0.5.1)
# Requirement already satisfied: uc-micro-py in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (from linkify-it-py->panel>=0.11.0->hvplot) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (from markdown-it-py->panel>=0.11.0->hvplot) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (from requests->panel>=0.11.0->hvplot) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (from requests->panel>=0.11.0->hvplot) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (from requests->panel>=0.11.0->hvplot) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/arthurverza/anaconda3/lib/python3.11/site-packages (from requests->panel>=0.11.0->hvplot) (2023.7.22)
# WARNING: Ignoring invalid distribution ~atplotlib (/Users/arthurverza/anaconda3/lib/python3.11/site-packages)
# Note: you may need to restart the kernel to use updated packages.

# %%
df.drop('Attrition', axis=1).corrwith(df.Attrition).hvplot.barh()
# Out:
# :Bars   [index]   (0)
